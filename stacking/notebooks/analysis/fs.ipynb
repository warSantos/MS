# %%
import numpy as np

# %%
fr = np.load("../../data/feature_selection/webkb/feature_ranking.npy")

# %%
fr
# Out:
# array([282,  33, 786,  32, 662, 534, 433, 661, 559, 536, 157, 537, 797,
#        787, 671, 156,  31, 545, 283,  29, 409, 410,  28, 408, 411, 406,
#        164, 160, 533, 660, 668, 284,  38, 165, 281, 306, 535, 685, 795,
#        790, 684, 556, 290, 159, 682, 291, 407, 785, 663, 789, 432, 542,
#        808,  52, 285,  40, 670, 416, 304, 436, 811, 301, 417, 178, 543,
#         41, 163, 594, 687, 683, 801, 544, 418, 462, 312,  45,  88, 816,
#        769, 793, 667, 305,  39, 809,  30, 155, 833, 562, 571, 435, 446,
#        340, 558, 557, 843,  58, 796, 810, 678, 338, 590, 419, 461, 675,
#         53, 195, 550,  57, 423, 712,  60, 715, 504,  69, 319,  55, 697,
#         54, 695, 440, 573,  44, 180,  36,  84, 171,  85, 821, 297,  67,
#        442, 191, 265, 387, 379, 464, 167, 540, 794,   3, 212, 823, 298,
#        763, 385, 844, 215, 182, 287, 425, 507, 292, 170, 569,  34, 316,
#        430, 303, 278,  86, 710, 759, 718, 447, 192, 806, 560, 641, 819,
# ...
