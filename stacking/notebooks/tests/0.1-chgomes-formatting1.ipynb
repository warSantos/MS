# %% [markdown]
# # Libraries

# %%
import os
import copy

import pandas as pd
import numpy as np

from distutils.dir_util import copy_tree
from sklearn.datasets import load_svmlight_file
from itertools import product

# %%
DATASET_INFO = {
    "20ng": 20,
    "acm": 11,
    "agnews": 4,
    "imdb_reviews": 10,
    "reut": 90,
    "sogou": 5,
    "yahoo": 10,
    "yelp_2015": 5,
    "webkb": 7
}

ID_MODEL = {
    "linear_svm/fast_text_1/raw_folds":            "sfr",
    "linear_svm/pte_1/raw_folds":                  "spr",
    "linear_svm/tf_idf_1/fs":                      "str",
    "linear_svm/tf_idf_1/meta_features_1/knn_cos": "stmk",
    "knn/fast_text_1/raw_folds":                   "kfr",
    "knn/pte_1/raw_folds":                         "kpr",
    "knn/tf_idf_1/fs":                             "ktr",
    "knn/tf_idf_1/meta_features_1/knn_cos":        "ktmk",
    "lr/fast_text_1/raw_folds":                    "lfr",
    "lr/pte_1/raw_folds":                          "lpr",
    "lr/tf_idf_1/fs":                              "ltr",
    "lr/tf_idf_1/meta_features_1/knn_cos":         "ltmk",
    "xgboost/fast_text_1/raw_folds":               "xfr",
    "xgboost/pte_1/raw_folds":                     "xpr",
    "xgboost/tf_idf_1/fs":                         "xtr",
    "xgboost/tf_idf_1/meta_features_1/knn_cos":    "xtmk",
    "xlnet":                                       "xlnet",
    "bert":                                        "bert"
}

DIR_PROJ_OLD = "/home/christian/arquivado/projeto_stacking"
DIR_PROJ_NEW = "/home/christian/stacking_text_classification"

MODELS = ID_MODEL.keys()
DATASETS = ["reut", "20ng", "acm", "webkb"]
SMALL_DATASETS = ["20ng", "acm", "webkb", "reut"]

# %% [markdown]
# # Formatting Meta-Layer Input

# %% [markdown]
# meta_layer:
# * test: probs do teste
# * train: probs do treino

# %%
for dataset, model in product(DATASETS, MODELS):
    # Configs
    model_id = ID_MODEL[model]
    n_folds = 10 if dataset in SMALL_DATASETS else 5
    print(dataset, model, model_id)

    # Execute each fold
    all_folds = list(range(n_folds))
    for fold_id in range(n_folds):
        # New files
        dir_fold = f"{DIR_PROJ_NEW}/data/meta_layer_input/{dataset}/{n_folds}_folds/{model_id}/{fold_id}"
        os.makedirs(dir_fold, exist_ok=True)
        file_train_new = f"{dir_fold}/train"
        file_test_new = f"{dir_fold}/test"
        
        # Skip if already executed
        if os.path.exists(f"{file_train_new}.npz") and os.path.exists(f"{file_test_new}.npz"):
            continue
            
        # Read test
        file_test_old = f"{DIR_PROJ_OLD}/output/classification/{dataset}/{n_folds}_folds/{model}/fold_{fold_id}/test.gz"
        X_test, y_test = load_svmlight_file(f=file_test_old, dtype=np.float64, zero_based=False, n_features=DATASET_INFO[dataset])
        X_test = X_test.toarray()
        
        # Read train
        train_folds = copy.deepcopy(all_folds)
        train_folds.remove(fold_id)
        
        X_train, y_train = [], []
        for fold_id_train in train_folds:
            file_train_old = f"{DIR_PROJ_OLD}/output/classification/{dataset}/{n_folds}_folds/{model}/fold_{fold_id_train}/test.gz"
            X_train_tmp, y_train_tmp = load_svmlight_file(f=file_train_old, dtype=np.float64, zero_based=False, n_features=DATASET_INFO[dataset])
            X_train_tmp = X_train_tmp.toarray()
            
            X_train.append(X_train_tmp)
            y_train.append(y_train_tmp)
        X_train = np.vstack(X_train)
        y_train = np.hstack(y_train)
        
        # Correct order train
        df_split = pd.read_pickle(f"{DIR_PROJ_OLD}/input/{dataset}/representations/{n_folds}_folds_splits.csv")
        df_split.drop(fold_id, axis=0, inplace=True)

        idxs_wrong = []
        for x in df_split["test_idxs"].values:
            idxs_wrong += x.tolist()
        idxs_correct = list(enumerate(idxs_wrong))
        idxs_correct = sorted(idxs_correct, key=lambda x: x[1])   
        idxs_correct = [x[0] for x in idxs_correct]
        
        X_train = X_train[idxs_correct]
        y_train = y_train[idxs_correct]
        
        break
    break
# Out:
# 20ng linear_svm/fast_text_1/raw_folds sfr
# 20ng linear_svm/pte_1/raw_folds spr
# 20ng linear_svm/tf_idf_1/fs str
# 20ng linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# 20ng knn/fast_text_1/raw_folds kfr
# 20ng knn/pte_1/raw_folds kpr
# 20ng knn/tf_idf_1/fs ktr
# 20ng knn/tf_idf_1/meta_features_1/knn_cos ktmk
# 20ng lr/fast_text_1/raw_folds lfr
# 20ng lr/pte_1/raw_folds lpr
# 20ng lr/tf_idf_1/fs ltr
# 20ng lr/tf_idf_1/meta_features_1/knn_cos ltmk
# 20ng xgboost/fast_text_1/raw_folds xfr
# 20ng xgboost/pte_1/raw_folds xpr
# 20ng xgboost/tf_idf_1/fs xtr
# 20ng xgboost/tf_idf_1/meta_features_1/knn_cos xtmk
# 20ng xlnet xlnet
# 20ng bert bert
# acm linear_svm/fast_text_1/raw_folds sfr
# acm linear_svm/pte_1/raw_folds spr
# acm linear_svm/tf_idf_1/fs str
# acm linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# acm knn/fast_text_1/raw_folds kfr
# acm knn/pte_1/raw_folds kpr
# acm knn/tf_idf_1/fs ktr
# acm knn/tf_idf_1/meta_features_1/knn_cos ktmk
# acm lr/fast_text_1/raw_folds lfr
# acm lr/pte_1/raw_folds lpr
# acm lr/tf_idf_1/fs ltr
# acm lr/tf_idf_1/meta_features_1/knn_cos ltmk
# acm xgboost/fast_text_1/raw_folds xfr
# acm xgboost/pte_1/raw_folds xpr
# acm xgboost/tf_idf_1/fs xtr
# acm xgboost/tf_idf_1/meta_features_1/knn_cos xtmk
# acm xlnet xlnet
# acm bert bert
# agnews linear_svm/fast_text_1/raw_folds sfr
# agnews linear_svm/pte_1/raw_folds spr
# agnews linear_svm/tf_idf_1/fs str
# agnews linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# agnews knn/fast_text_1/raw_folds kfr
# agnews knn/pte_1/raw_folds kpr
# agnews knn/tf_idf_1/fs ktr
# agnews knn/tf_idf_1/meta_features_1/knn_cos ktmk
# agnews lr/fast_text_1/raw_folds lfr
# agnews lr/pte_1/raw_folds lpr
# agnews lr/tf_idf_1/fs ltr
# agnews lr/tf_idf_1/meta_features_1/knn_cos ltmk
# agnews xgboost/fast_text_1/raw_folds xfr
# agnews xgboost/pte_1/raw_folds xpr
# agnews xgboost/tf_idf_1/fs xtr
# agnews xgboost/tf_idf_1/meta_features_1/knn_cos xtmk
# agnews xlnet xlnet
# agnews bert bert
# imdb_reviews linear_svm/fast_text_1/raw_folds sfr
# imdb_reviews linear_svm/pte_1/raw_folds spr
# imdb_reviews linear_svm/tf_idf_1/fs str
# imdb_reviews linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# imdb_reviews knn/fast_text_1/raw_folds kfr
# imdb_reviews knn/pte_1/raw_folds kpr
# imdb_reviews knn/tf_idf_1/fs ktr
# imdb_reviews knn/tf_idf_1/meta_features_1/knn_cos ktmk
# imdb_reviews lr/fast_text_1/raw_folds lfr
# imdb_reviews lr/pte_1/raw_folds lpr
# imdb_reviews lr/tf_idf_1/fs ltr
# imdb_reviews lr/tf_idf_1/meta_features_1/knn_cos ltmk
# imdb_reviews xgboost/fast_text_1/raw_folds xfr
# imdb_reviews xgboost/pte_1/raw_folds xpr
# imdb_reviews xgboost/tf_idf_1/fs xtr
# imdb_reviews xgboost/tf_idf_1/meta_features_1/knn_cos xtmk
# imdb_reviews xlnet xlnet
# imdb_reviews bert bert
# reut linear_svm/fast_text_1/raw_folds sfr
# reut linear_svm/pte_1/raw_folds spr
# reut linear_svm/tf_idf_1/fs str
# reut linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# reut knn/fast_text_1/raw_folds kfr
# reut knn/pte_1/raw_folds kpr
# reut knn/tf_idf_1/fs ktr
# reut knn/tf_idf_1/meta_features_1/knn_cos ktmk
# reut lr/fast_text_1/raw_folds lfr
# reut lr/pte_1/raw_folds lpr
# reut lr/tf_idf_1/fs ltr
# reut lr/tf_idf_1/meta_features_1/knn_cos ltmk
# reut xgboost/fast_text_1/raw_folds xfr
# reut xgboost/pte_1/raw_folds xpr
# reut xgboost/tf_idf_1/fs xtr
# reut xgboost/tf_idf_1/meta_features_1/knn_cos xtmk
# reut xlnet xlnet
# reut bert bert
# sogou linear_svm/fast_text_1/raw_folds sfr
# sogou linear_svm/pte_1/raw_folds spr
# sogou linear_svm/tf_idf_1/fs str
# sogou linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# sogou knn/fast_text_1/raw_folds kfr
# sogou knn/pte_1/raw_folds kpr
# sogou knn/tf_idf_1/fs ktr
# sogou knn/tf_idf_1/meta_features_1/knn_cos ktmk
# sogou lr/fast_text_1/raw_folds lfr
# sogou lr/pte_1/raw_folds lpr
# sogou lr/tf_idf_1/fs ltr
# sogou lr/tf_idf_1/meta_features_1/knn_cos ltmk
# sogou xgboost/fast_text_1/raw_folds xfr
# sogou xgboost/pte_1/raw_folds xpr
# sogou xgboost/tf_idf_1/fs xtr
# sogou xgboost/tf_idf_1/meta_features_1/knn_cos xtmk
# sogou xlnet xlnet
# sogou bert bert
# yahoo linear_svm/fast_text_1/raw_folds sfr
# 	 0 (292000, 10) (1168000, 10)
# 	 1 (292000, 10) (1168000, 10)
# 	 2 (292000, 10) (1168000, 10)
# 	 3 (292000, 10) (1168000, 10)
# 	 4 (292000, 10) (1168000, 10)
# yahoo linear_svm/pte_1/raw_folds spr
# 	 0 (292000, 10) (1168000, 10)
# 	 1 (292000, 10) (1168000, 10)
# 	 2 (292000, 10) (1168000, 10)
# 	 3 (292000, 10) (1168000, 10)
# 	 4 (292000, 10) (1168000, 10)
# yahoo linear_svm/tf_idf_1/fs str
# 	 0 (292000, 10) (1168000, 10)
# 	 1 (292000, 10) (1168000, 10)
# 	 2 (292000, 10) (1168000, 10)
# 	 3 (292000, 10) (1168000, 10)
# 	 4 (292000, 10) (1168000, 10)
# yahoo linear_svm/tf_idf_1/meta_features_1/knn_cos stmk
# 	 0 (292000, 10) (1168000, 10)
# 	 1 (292000, 10) (1168000, 10)
# 	 2 (292000, 10) (1168000, 10)
# 	 3 (292000, 10) (1168000, 10)
# 	 4 (292000, 10) (1168000, 10)
# yahoo knn/fast_text_1/raw_folds kfr
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-697e0fe6f5e2> in <module>
#      74                 f'/{n_folds}_folds/{alg}/fold_{fold_id_train}/test.gz'
#      75             )
# ---> 76             X_train_tmp, y_train_tmp = load_svmlight_file(f=train_old, dtype=np.float64, zero_based=False,
#      77                                                 n_features=dset_infos[dset])
#      78             X_train_tmp = X_train_tmp.toarray()
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/site-packages/sklearn/datasets/_svmlight_format_io.py in load_svmlight_file(f, n_features, dtype, multilabel, zero_based, query_id, offset, length)
#     162     """
#     163     return tuple(
# --> 164         load_svmlight_files(
#     165             [f],
#     166             n_features=n_features,
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/site-packages/sklearn/datasets/_svmlight_format_io.py in load_svmlight_files(files, n_features, dtype, multilabel, zero_based, query_id, offset, length)
#     320         raise ValueError("n_features is required when offset or length is specified.")
#     321
# --> 322     r = [
#     323         _open_and_load(
#     324             f,
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/site-packages/sklearn/datasets/_svmlight_format_io.py in <listcomp>(.0)
#     321
#     322     r = [
# --> 323         _open_and_load(
#     324             f,
#     325             dtype,
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/site-packages/sklearn/datasets/_svmlight_format_io.py in _open_and_load(f, dtype, multilabel, zero_based, query_id, offset, length)
#     200         )
#     201     else:
# --> 202         with closing(_gen_open(f)) as f:
#     203             actual_dtype, data, ind, indptr, labels, query = _load_svmlight_file(
#     204                 f, dtype, multilabel, zero_based, query_id, offset, length
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/site-packages/sklearn/datasets/_svmlight_format_io.py in _gen_open(f)
#     185         import gzip
#     186
# --> 187         return gzip.open(f, "rb")
#     188     elif ext == ".bz2":
#     189         from bz2 import BZ2File
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ~/anaconda3/envs/stacking-text-classification/lib/python3.9/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#     175             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/christian/arquivado/projeto_stacking/output/classification/yahoo/5_folds/knn/fast_text_1/raw_folds/fold_1/test.gz'
