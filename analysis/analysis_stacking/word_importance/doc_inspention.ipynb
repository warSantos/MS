# %%
import numpy as np
import pandas as pd

from sys import path

path.append('../utils/')

from utils import get_datatasets

# %%
DATASETS = ["20ng", "acm", "webkb", "reut"]

ALGORITHMS = ["centroide", "gbm", "knn", "lr", "rf", "svm", "bert"]

# %%
base_path = "/home/welton/data/datasets/pandas/bert/__dset__.csv"
pd_datasets = get_datatasets(DATASETS, path=base_path, sep=';')

# %%
df = pd_datasets["webkb"]

# %%
df[(df.conc_size == 7) & (df.hits_count == 0)]
# Out:
#       centroide  gbm  knn  lr  rf  svm  bert  hits_count  conc_pred  \
# 13            1    1    1   1   1    1     1           0          1
# 24            1    1    1   1   1    1     1           0          1
# 32            1    1    1   1   1    1     1           0          1
# 34            1    1    1   1   1    1     1           0          1
# 40            5    5    5   5   5    5     5           0          5
# ...         ...  ...  ...  ..  ..  ...   ...         ...        ...
# 8118          0    0    0   0   0    0     0           0          0
# 8141          1    1    1   1   1    1     1           0          1
# 8165          0    0    0   0   0    0     0           0          0
# 8174          3    3    3   3   3    3     3           0          3
# 8194          1    1    1   1   1    1     1           0          1
#
#       conc_size  classes                                               docs  \
# ...

# %%
df.columns
# Out:
# Index(['centroide', 'gbm', 'knn', 'lr', 'rf', 'svm', 'bert', 'conc_pred',
#        'conc_size', 'classes', 'docs', 'folds_id'],
#       dtype='object')
